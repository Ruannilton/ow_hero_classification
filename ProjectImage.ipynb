# %%
import os, shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
pathname = './heroes/'

# %%
#Prepara lista de tags assumindo que os arquivos estao em pastas nomeadas
def get_taglist(path="./heroes/"):    
    names = [x[0] for x in os.walk(path)]
    names = [n[len(path):] for n in names]
    names = [n for n in names if n ]
    if ".ipynb_checkpoints" in names:
        names.remove(".ipynb_checkpoints")
    if "train" in names:
        names.remove("train")
    if "valid" in names:
        names.remove("valid")
    if "test" in names:
        names.remove("test")
    
    return names

# %%
tags = get_taglist()

# %%
print(tags)
# Out:
# ['ana', 'ashe', 'baptiste', 'bastion', 'brigitte', 'd.va', 'doomfist', 'echo', 'genji', 'hanzo', 'junkrat', 'lucio', 'mccree', 'mei', 'mercy', 'moira', 'orisa', 'pharah', 'reaper', 'reinhardt', 'roadrog', 'soldier76', 'sombra', 'symmetra', 'torbjorn', 'tracer', 'widowmaker', 'winston', 'zarya', 'zenyatta']

# %%
#Prepara pastas de treino, validacao e teste
def prepare_folders(path = "./heroes"):
    train_dir = os.path.join(path, 'train')
    if not os.path.exists(train_dir):
        print(f" step1 creating {train_dir}")
        os.mkdir(train_dir)
    valid_dir = os.path.join(path, 'valid')
    if not os.path.exists(valid_dir):
        print(f" step1 creating {valid_dir}")
        os.mkdir(valid_dir)
    test_dir = os.path.join(path, 'test')
    if not os.path.exists(test_dir):
        print(f" step1 creating {test_dir}")
        os.mkdir(test_dir)
    
    named_train_dirs = {}
    for tag in tags:
        name = os.path.join(train_dir, tag)
        print(name)
        named_train_dirs[tag] = name
        
    for p in named_train_dirs:
        if not os.path.exists(named_train_dirs[p]):
            print(f"creating {named_train_dirs[p]}")
            os.mkdir(named_train_dirs[p])    
    
    named_valid_dirs = {}
    for tag in tags:
        name = os.path.join(valid_dir, tag) 
        print(name)
        named_valid_dirs[tag] = name
        
    for p in named_valid_dirs:
        if not os.path.exists(named_valid_dirs[p]):
            print(f"creating {named_valid_dirs[p]}")
            os.mkdir(named_valid_dirs[p])
        
    named_test_dirs = {}
    for tag in tags:
        name = os.path.join(test_dir, tag) 
        print(name)
        named_test_dirs[tag] = os.path.join(test_dir, tag)
        
        for p in named_test_dirs:
            if not os.path.exists(named_test_dirs[p]):
                print(f"creating {named_test_dirs[p]}")
                os.mkdir(named_test_dirs[p])

                
    return (train_dir, valid_dir, test_dir, named_train_dirs, named_valid_dirs, named_test_dirs)

# %%
dirs = prepare_folders()
# Out:
#  step1 creating ./heroes\train
#  step1 creating ./heroes\valid
#  step1 creating ./heroes\test
# ./heroes\train\ana
# ./heroes\train\ashe
# ./heroes\train\baptiste
# ./heroes\train\bastion
# ./heroes\train\brigitte
# ./heroes\train\d.va
# ./heroes\train\doomfist
# ./heroes\train\echo
# ./heroes\train\genji
# ./heroes\train\hanzo
# ./heroes\train\junkrat
# ./heroes\train\lucio
# ./heroes\train\mccree
# ./heroes\train\mei
# ./heroes\train\mercy
# ./heroes\train\moira
# ./heroes\train\orisa
# ./heroes\train\pharah
# ./heroes\train\reaper
# ./heroes\train\reinhardt
# ./heroes\train\roadrog
# ./heroes\train\soldier76
# ./heroes\train\sombra
# ./heroes\train\symmetra
# ./heroes\train\torbjorn
# ./heroes\train\tracer
# ./heroes\train\widowmaker
# ./heroes\train\winston
# ./heroes\train\zarya
# ./heroes\train\zenyatta
# creating ./heroes\train\ana
# creating ./heroes\train\ashe
# creating ./heroes\train\baptiste
# creating ./heroes\train\bastion
# creating ./heroes\train\brigitte
# creating ./heroes\train\d.va
# creating ./heroes\train\doomfist
# creating ./heroes\train\echo
# creating ./heroes\train\genji
# creating ./heroes\train\hanzo
# creating ./heroes\train\junkrat
# creating ./heroes\train\lucio
# creating ./heroes\train\mccree
# creating ./heroes\train\mei
# creating ./heroes\train\mercy
# creating ./heroes\train\moira
# creating ./heroes\train\orisa
# creating ./heroes\train\pharah
# creating ./heroes\train\reaper
# creating ./heroes\train\reinhardt
# creating ./heroes\train\roadrog
# creating ./heroes\train\soldier76
# creating ./heroes\train\sombra
# creating ./heroes\train\symmetra
# creating ./heroes\train\torbjorn
# creating ./heroes\train\tracer
# creating ./heroes\train\widowmaker
# creating ./heroes\train\winston
# creating ./heroes\train\zarya
# creating ./heroes\train\zenyatta
# ./heroes\valid\ana
# ./heroes\valid\ashe
# ./heroes\valid\baptiste
# ./heroes\valid\bastion
# ./heroes\valid\brigitte
# ./heroes\valid\d.va
# ./heroes\valid\doomfist
# ./heroes\valid\echo
# ./heroes\valid\genji
# ./heroes\valid\hanzo
# ./heroes\valid\junkrat
# ./heroes\valid\lucio
# ./heroes\valid\mccree
# ./heroes\valid\mei
# ./heroes\valid\mercy
# ./heroes\valid\moira
# ./heroes\valid\orisa
# ./heroes\valid\pharah
# ./heroes\valid\reaper
# ./heroes\valid\reinhardt
# ./heroes\valid\roadrog
# ./heroes\valid\soldier76
# ./heroes\valid\sombra
# ./heroes\valid\symmetra
# ./heroes\valid\torbjorn
# ./heroes\valid\tracer
# ./heroes\valid\widowmaker
# ./heroes\valid\winston
# ./heroes\valid\zarya
# ./heroes\valid\zenyatta
# creating ./heroes\valid\ana
# creating ./heroes\valid\ashe
# creating ./heroes\valid\baptiste
# creating ./heroes\valid\bastion
# creating ./heroes\valid\brigitte
# creating ./heroes\valid\d.va
# creating ./heroes\valid\doomfist
# creating ./heroes\valid\echo
# creating ./heroes\valid\genji
# creating ./heroes\valid\hanzo
# creating ./heroes\valid\junkrat
# creating ./heroes\valid\lucio
# creating ./heroes\valid\mccree
# creating ./heroes\valid\mei
# creating ./heroes\valid\mercy
# creating ./heroes\valid\moira
# creating ./heroes\valid\orisa
# creating ./heroes\valid\pharah
# creating ./heroes\valid\reaper
# creating ./heroes\valid\reinhardt
# creating ./heroes\valid\roadrog
# creating ./heroes\valid\soldier76
# creating ./heroes\valid\sombra
# creating ./heroes\valid\symmetra
# creating ./heroes\valid\torbjorn
# creating ./heroes\valid\tracer
# creating ./heroes\valid\widowmaker
# creating ./heroes\valid\winston
# creating ./heroes\valid\zarya
# creating ./heroes\valid\zenyatta
# ./heroes\test\ana
# creating ./heroes\test\ana
# ./heroes\test\ashe
# creating ./heroes\test\ashe
# ./heroes\test\baptiste
# creating ./heroes\test\baptiste
# ./heroes\test\bastion
# creating ./heroes\test\bastion
# ./heroes\test\brigitte
# creating ./heroes\test\brigitte
# ./heroes\test\d.va
# creating ./heroes\test\d.va
# ./heroes\test\doomfist
# creating ./heroes\test\doomfist
# ./heroes\test\echo
# creating ./heroes\test\echo
# ./heroes\test\genji
# creating ./heroes\test\genji
# ./heroes\test\hanzo
# creating ./heroes\test\hanzo
# ./heroes\test\junkrat
# creating ./heroes\test\junkrat
# ./heroes\test\lucio
# creating ./heroes\test\lucio
# ./heroes\test\mccree
# creating ./heroes\test\mccree
# ./heroes\test\mei
# creating ./heroes\test\mei
# ./heroes\test\mercy
# creating ./heroes\test\mercy
# ./heroes\test\moira
# creating ./heroes\test\moira
# ./heroes\test\orisa
# creating ./heroes\test\orisa
# ./heroes\test\pharah
# creating ./heroes\test\pharah
# ./heroes\test\reaper
# creating ./heroes\test\reaper
# ./heroes\test\reinhardt
# creating ./heroes\test\reinhardt
# ./heroes\test\roadrog
# creating ./heroes\test\roadrog
# ./heroes\test\soldier76
# creating ./heroes\test\soldier76
# ./heroes\test\sombra
# creating ./heroes\test\sombra
# ./heroes\test\symmetra
# creating ./heroes\test\symmetra
# ./heroes\test\torbjorn
# creating ./heroes\test\torbjorn
# ./heroes\test\tracer
# creating ./heroes\test\tracer
# ./heroes\test\widowmaker
# creating ./heroes\test\widowmaker
# ./heroes\test\winston
# creating ./heroes\test\winston
# ./heroes\test\zarya
# creating ./heroes\test\zarya
# ./heroes\test\zenyatta
# creating ./heroes\test\zenyatta

# %%
train_dir, valid_dir, test_dir, named_train_dirs, named_valid_dirs, named_test_dirs = dirs

# %%
# copia os dados para pasta de treino
for tag in tags:    
    print(f"In {tag}")     
    match = [f for f in os.listdir(pathname+f"{tag}") if f[0].isdigit()]    
    train_fac = 0.5 
    match_length = int(len(match)*train_fac)
    print(match_length)
    for i in range(match_length):
        src = os.path.join(pathname+f"{tag}", match[i])
        dst = os.path.join(named_train_dirs[tag], match[i])
        print(f"copying from {src} to {dst}")
        shutil.copyfile(src, dst)
# Out:
# symmetra\00000044.png
# copying from ./heroes/symmetra\00000045.jpg to ./heroes\train\symmetra\00000045.jpg
# copying from ./heroes/symmetra\00000046.png to ./heroes\train\symmetra\00000046.png
# In torbjorn
# 38
# copying from ./heroes/torbjorn\00000000.jpg to ./heroes\train\torbjorn\00000000.jpg
# copying from ./heroes/torbjorn\00000001.png to ./heroes\train\torbjorn\00000001.png
# copying from ./heroes/torbjorn\00000002.jpg to ./heroes\train\torbjorn\00000002.jpg
# copying from ./heroes/torbjorn\00000003.png to ./heroes\train\torbjorn\00000003.png
# copying from ./heroes/torbjorn\00000004.jpg to ./heroes\train\torbjorn\00000004.jpg
# copying from ./heroes/torbjorn\00000005.jpg to ./heroes\train\torbjorn\00000005.jpg
# copying from ./heroes/torbjorn\00000006.jpg to ./heroes\train\torbjorn\00000006.jpg
# copying from ./heroes/torbjorn\00000007.png to ./heroes\train\torbjorn\00000007.png
# copying from ./heroes/torbjorn\00000008.jpg to ./heroes\train\torbjorn\00000008.jpg
# copying from ./heroes/torbjorn\00000009.jpg to ./heroes\train\torbjorn\00000009.jpg
# copying from ./heroes/torbjorn\00000010.png to ./heroes\train\torbjorn\00000010.png
# copying from ./heroes/torbjorn\00000011.png to ./heroes\train\torbjorn\00000011.png
# copying from ./heroes/torbjorn\00000012.jpg to ./heroes\train\torbjorn\00000012.jpg
# copying from ./heroes/torbjorn\00000013.jpg to ./heroes\train\torbjorn\00000013.jpg
# copying from ./heroes/torbjorn\00000014.png to ./heroes\train\torbjorn\00000014.png
# copying from ./heroes/torbjorn\00000015.jpg to ./heroes\train\torbjorn\00000015.jpg
# copying from ./heroes/torbjorn\00000016.jpg to ./heroes\train\torbjorn\00000016.jpg
# copying from ./heroes/torbjorn\00000017.jpg to ./heroes\train\torbjorn\00000017.jpg
# copying from ./heroes/torbjorn\00000018.jpg to ./heroes\train\torbjorn\00000018.jpg
# copying from ./heroes/torbjorn\00000019.jpg to ./heroes\train\torbjorn\00000019.jpg
# copying from ./heroes/torbjorn\00000021.jpg to ./heroes\train\torbjorn\00000021.jpg
# copying from ./heroes/torbjorn\00000022.jpg to ./heroes\train\torbjorn\00000022.jpg
# copying from ./heroes/torbjorn\00000023.png to ./heroes\train\torbjorn\00000023.png
# copying from ./heroes/torbjorn\00000024.jpg to ./heroes\train\torbjorn\00000024.jpg
# copying from ./heroes/torbjorn\00000025.jpg to ./heroes\train\torbjorn\00000025.jpg
# copying from ./heroes/torbjorn\00000026.jpg to ./heroes\train\torbjorn\00000026.jpg
# copying from ./heroes/torbjorn\00000027.jpg to ./heroes\train\torbjorn\00000027.jpg
# copying from ./heroes/torbjorn\00000029.jpg to ./heroes\train\torbjorn\00000029.jpg
# copying from ./heroes/torbjorn\00000031.jpg to ./heroes\train\torbjorn\00000031.jpg
# copying from ./heroes/torbjorn\00000032.jpg to ./heroes\train\torbjorn\00000032.jpg
# copying from ./heroes/torbjorn\00000033.png to ./heroes\train\torbjorn\00000033.png
# copying from ./heroes/torbjorn\00000035.png to ./heroes\train\torbjorn\00000035.png
# copying from ./heroes/torbjorn\00000036.png to ./heroes\train\torbjorn\00000036.png
# copying from ./heroes/torbjorn\00000037.jpg to ./heroes\train\torbjorn\00000037.jpg
# copying from ./heroes/torbjorn\00000038.jpg to ./heroes\train\torbjorn\00000038.jpg
# copying from ./heroes/torbjorn\00000039.jpg to ./heroes\train\torbjorn\00000039.jpg
# copying from ./heroes/torbjorn\00000041.jpg to ./heroes\train\torbjorn\00000041.jpg
# copying from ./heroes/torbjorn\00000042.jpg to ./heroes\train\torbjorn\00000042.jpg
# In tracer
# 41
# copying from ./heroes/tracer\00000000.png to ./heroes\train\tracer\00000000.png
# copying from ./heroes/tracer\00000001.jpg to ./heroes\train\tracer\00000001.jpg
# copying from ./heroes/tracer\00000002.jpg to ./heroes\train\tracer\00000002.jpg
# copying from ./heroes/tracer\00000003.jpg to ./heroes\train\tracer\00000003.jpg
# copying from ./heroes/tracer\00000004.jpg to ./heroes\train\tracer\00000004.jpg
# copying from ./heroes/tracer\00000005.jpg to ./heroes\train\tracer\00000005.jpg
# copying from ./heroes/tracer\00000006.jpg to ./heroes\train\tracer\00000006.jpg
# copying from ./heroes/zenyatta\00000034.jpg to ./heroes\train\zenyatta\00000034.jpg
# copying from ./heroes/zenyatta\00000038.jpg to ./heroes\train\zenyatta\00000038.jpg
# copying from ./heroes/zenyatta\00000039.png to ./heroes\train\zenyatta\00000039.png
# copying from ./heroes/zenyatta\00000040.jpg to ./heroes\train\zenyatta\00000040.jpg
# copying from ./heroes/zenyatta\00000041.jpg to ./heroes\train\zenyatta\00000041.jpg
# copying from ./heroes/zenyatta\00000042.png to ./heroes\train\zenyatta\00000042.png
# copying from ./heroes/zenyatta\00000043.jpg to ./heroes\train\zenyatta\00000043.jpg
# copying from ./heroes/zenyatta\00000044.jpg to ./heroes\train\zenyatta\00000044.jpg
# copying from ./heroes/zenyatta\00000045.jpg to ./heroes\train\zenyatta\00000045.jpg

# %%
#copia os dados para pasta de validacao
for tag in tags:  
    print(f"In {tag}")     
    match = [f for f in os.listdir(pathname+f"{tag}") if f[0].isdigit()]   
    train_fac = 0.5 
    valid_fac = 0.3
    train_length = int(len(match)*train_fac)
    valid_length = train_length + int(len(match)*valid_fac)
    for i in range(train_length, valid_length, 1):
        src = os.path.join(pathname+f"{tag}", match[i])
        dst = os.path.join(named_valid_dirs[tag], match[i])
        print(f"copying from {src} to {dst}")
        shutil.copyfile(src, dst)
# Out:
# r\00000073.jpg to ./heroes\valid\reaper\00000073.jpg
# copying from ./heroes/reaper\00000074.png to ./heroes\valid\reaper\00000074.png
# In reinhardt
# copying from ./heroes/reinhardt\00000043.jpg to ./heroes\valid\reinhardt\00000043.jpg
# copying from ./heroes/reinhardt\00000044.jpg to ./heroes\valid\reinhardt\00000044.jpg
# copying from ./heroes/reinhardt\00000045.jpg to ./heroes\valid\reinhardt\00000045.jpg
# copying from ./heroes/reinhardt\00000046.jpg to ./heroes\valid\reinhardt\00000046.jpg
# copying from ./heroes/reinhardt\00000047.jpg to ./heroes\valid\reinhardt\00000047.jpg
# copying from ./heroes/reinhardt\00000048.jpg to ./heroes\valid\reinhardt\00000048.jpg
# copying from ./heroes/reinhardt\00000049.jpg to ./heroes\valid\reinhardt\00000049.jpg
# copying from ./heroes/reinhardt\00000050.jpg to ./heroes\valid\reinhardt\00000050.jpg
# copying from ./heroes/reinhardt\00000051.png to ./heroes\valid\reinhardt\00000051.png
# copying from ./heroes/reinhardt\00000052.jpg to ./heroes\valid\reinhardt\00000052.jpg
# copying from ./heroes/reinhardt\00000055.jpg to ./heroes\valid\reinhardt\00000055.jpg
# copying from ./heroes/reinhardt\00000056.jpg to ./heroes\valid\reinhardt\00000056.jpg
# copying from ./heroes/reinhardt\00000057.jpg to ./heroes\valid\reinhardt\00000057.jpg
# copying from ./heroes/reinhardt\00000058.jpg to ./heroes\valid\reinhardt\00000058.jpg
# copying from ./heroes/reinhardt\00000060.jpg to ./heroes\valid\reinhardt\00000060.jpg
# copying from ./heroes/reinhardt\00000062.png to ./heroes\valid\reinhardt\00000062.png
# copying from ./heroes/reinhardt\00000063.png to ./heroes\valid\reinhardt\00000063.png
# copying from ./heroes/reinhardt\00000064.jpg to ./heroes\valid\reinhardt\00000064.jpg
# copying from ./heroes/reinhardt\00000065.jpg to ./heroes\valid\reinhardt\00000065.jpg
# copying from ./heroes/reinhardt\00000066.jpg to ./heroes\valid\reinhardt\00000066.jpg
# copying from ./heroes/reinhardt\00000067.jpg to ./heroes\valid\reinhardt\00000067.jpg
# copying from ./heroes/reinhardt\00000069.jpg to ./heroes\valid\reinhardt\00000069.jpg
# copying from ./heroes/reinhardt\00000070.jpg to ./heroes\valid\reinhardt\00000070.jpg
# In roadrog
# copying from ./heroes/roadrog\128-1289926_female-roadhog-roadhog-as-a-girl-hd-png.png to ./heroes\valid\roadrog\128-1289926_female-roadhog-roadhog-as-a-girl-hd-png.png
# In soldier76
# copying from ./heroes/soldier76\00000047.png to ./heroes\valid\soldier76\00000047.png
# copying from ./heroes/soldier76\00000049.jpg to ./heroes\valid\soldier76\00000049.jpg
# copying from ./heroes/soldier76\00000050.jpg to ./heroes\valid\soldier76\00000050.jpg
# copying from ./heroes/soldier76\00000051.jpg to ./heroes\valid\soldier76\00000051.jpg
# copying from ./heroes/soldier76\00000052.jpg to ./heroes\valid\soldier76\00000052.jpg
# copying from ./heroes/soldier76\00000053.jpg to ./heroes\valid\soldier76\00000053.jpg
# copying from ./heroes/soldier76\00000054.png to ./heroes\valid\soldier76\00000054.png
# copying from ./heroes/soldier76\00000056.jpg to ./heroes\valid\soldier76\00000056.jpg
# copying from ./heroes/soldier76\00000057.jpg to ./heroes\valid\soldier76\00000057.jpg
# copying from ./heroes/soldier76\00000058.png to ./heroes\valid\soldier76\00000058.png
# copying from ./heroes/soldier76\00000059.jpg to ./heroes\valid\soldier76\00000059.jpg
# copying from ./heroes/soldier76\00000060.jpg to ./heroes\valid\soldier76\00000060.jpg
# copying from ./heroes/soldier76\00000061.jpg to ./heroes\valid\soldier76\00000061.jpg
# copying from ./heroes/soldier76\00000062.jpg to ./heroes\valid\soldier76\00000062.jpg
# copying from ./heroes/soldier76\00000064.jpg to ./heroes\valid\soldier76\00000064.jpg
# copying from ./heroes/soldier76\00000065.jpg to ./heroes\valid\soldier76\00000065.jpg
# copying from ./heroes/soldier76\00000066.png to ./heroes\valid\soldier76\00000066.png
# copying from ./heroes/soldier76\00000067.jpg to ./heroes\valid\soldier76\00000067.jpg
# copying from ./heroes/soldier76\00000068.jpg to ./heroes\valid\soldier76\00000068.jpg
# copying from ./heroes/soldier76\00000069.jpg to ./heroes\valid\soldier76\00000069.jpg
# copying from ./heroes/soldier76\00000070.jpg to ./heroes\valid\soldier76\00000070.jpg
# copying from ./heroes/soldier76\00000071.jpg to ./heroes\valid\soldier76\00000071.jpg
# copying from ./heroes/soldier76\00000073.png to ./heroes\valid\soldier76\00000073.png
# copying from ./heroes/soldier76\00000074.jpg to ./heroes\valid\soldier76\00000074.jpg
# In sombra
# copying from ./heroes/sombra\00000041.jpeg to ./heroes\valid\sombra\00000041.jpeg
# copying from ./heroes/sombra\00000042.png to ./heroes\valid\sombra\00000042.png
# copying from ./heroes/sombra\00000043.jpg to ./heroes\valid\sombra\00000043.jpg
# copying from ./heroes/sombra\00000045.jpg to ./heroes\valid\sombra\00000045.jpg
# copying from ./heroes/sombra\00000046.png to ./heroes\valid\sombra\00000046.png
# copying from ./heroes/sombra\00000047.jpg to ./heroes\valid\sombra\00000047.jpg
# copying from ./heroes/sombra\00000048.jpg to ./heroes\valid\sombra\00000048.jpg
# copying from ./heroes/sombra\00000049.jpg to ./heroes\valid\sombra\00000049.jpg
# copying from ./heroes/sombra\00000050.jpg to ./heroes\valid\sombra\00000050.jpg
# copying from ./heroes/sombra\00000051.jpg to ./heroes\valid\sombra\00000051.jpg
# copying from ./heroes/sombra\00000052.jpg to ./heroes\valid\sombra\00000052.jpg
# copying from ./heroes/sombra\00000053.png to ./heroes\valid\sombra\00000053.png
# copying from ./heroes/sombra\00000054.jpg to ./heroes\valid\sombra\00000054.jpg
# copying from ./heroes/sombra\00000055.jpg to ./heroes\valid\sombra\00000055.jpg
# copying from ./heroes/sombra\00000056.jpg to ./heroes\valid\sombra\00000056.jpg
# copying from ./heroes/sombra\00000057.jpg to ./heroes\valid\sombra\00000057.jpg
# copying from ./heroes/sombra\00000060.jpg to ./heroes\valid\sombra\00000060.jpg
# copying from ./heroes/sombra\00000061.jpg to ./heroes\valid\sombra\00000061.jpg
# copying from ./heroes/sombra\00000062.jpg to ./heroes\valid\sombra\00000062.jpg
# copying from ./heroes/sombra\00000064.jpg to ./heroes\valid\sombra\00000064.jpg
# copying from ./heroes/sombra\00000065.jpg to ./heroes\valid\sombra\00000065.jpg
# copying from ./heroes/sombra\00000066.jpg to ./heroes\valid\sombra\00000066.jpg
# copying from ./heroes/sombra\00000067.jpg to ./heroes\valid\sombra\00000067.jpg
# copying from ./heroes/sombra\00000068.jpg to ./heroes\valid\sombra\00000068.jpg
# In symmetra
# copying from ./heroes/symmetra\00000048.png to ./heroes\valid\symmetra\00000048.png
# copying from ./heroes/symmetra\00000049.jpg to ./heroes\valid\symmetra\00000049.jpg
# copying from ./heroes/symmetra\00000051.jpg to ./heroes\valid\symmetra\00000051.jpg
# copying from ./heroes/symmetra\00000052.png to ./heroes\valid\symmetra\00000052.png
# copying from ./heroes/symmetra\00000054.jpg to ./heroes\valid\symmetra\00000054.jpg
# copying from ./heroes/symmetra\00000055.jpg to ./heroes\valid\symmetra\00000055.jpg
# copying from ./heroes/symmetra\00000056.jpeg to ./heroes\valid\symmetra\00000056.jpeg
# copying from ./heroes/symmetra\00000057.jpg to ./heroes\valid\symmetra\00000057.jpg
# copying from ./heroes/symmetra\00000058.png to ./heroes\valid\symmetra\00000058.png
# copying from ./heroes/symmetra\00000060.png to ./heroes\valid\symmetra\00000060.png
# copying from ./heroes/symmetra\00000061.jpg to ./heroes\valid\symmetra\00000061.jpg
# copying from ./heroes/symmetra\00000062.jpg to ./heroes\valid\symmetra\00000062.jpg
# copying from ./heroes/symmetra\00000063.jpg to ./heroes\valid\symmetra\00000063.jpg
# copying from ./heroes/symmetra\00000064.jpg to ./heroes\valid\symmetra\00000064.jpg
# copying from ./heroes/symmetra\00000065.png to ./heroes\valid\symmetra\00000065.png
# copying from ./heroes/symmetra\00000068.jpg to ./heroes\valid\symmetra\00000068.jpg
# copying from ./heroes/symmetra\00000069.jpg to ./heroes\valid\symmetra\00000069.jpg
# copying from ./heroes/symmetra\00000071.png to ./heroes\valid\symmetra\00000071.png
# copying from ./heroes/symmetra\00000072.jpg to ./heroes\valid\symmetra\00000072.jpg
# copying from ./heroes/symmetra\00000073.jpg to ./heroes\valid\symmetra\00000073.jpg
# copying from ./heroes/symmetra\00000074.jpg to ./heroes\valid\symmetra\00000074.jpg
# copying from ./heroes/symmetra\00000075.png to ./heroes\valid\symmetra\00000075.png
# In torbjorn
# copying from ./heroes/torbjorn\00000043.jpg to ./heroes\valid\torbjorn\00000043.jpg
# copying from ./heroes/torbjorn\00000044.jpg to ./heroes\valid\torbjorn\00000044.jpg
# copying from ./heroes/torbjorn\00000045.jpg to ./heroes\valid\torbjorn\00000045.jpg
# copying from ./heroes/torbjorn\00000046.png to ./heroes\valid\torbjorn\00000046.png
# copying from ./heroes/torbjorn\00000048.png to ./heroes\valid\torbjorn\00000048.png
# copying from ./heroes/torbjorn\00000049.png to ./heroes\valid\torbjorn\00000049.png
# copying from ./heroes/torbjorn\00000051.jpg to ./heroes\valid\torbjorn\00000051.jpg
# copying from ./heroes/torbjorn\00000053.jpg to ./heroes\valid\torbjorn\00000053.jpg
# copying from ./heroes/torbjorn\00000055.jpg to ./heroes\valid\torbjorn\00000055.jpg
# copying from ./heroes/torbjorn\00000056.jpg to ./heroes\valid\torbjorn\00000056.jpg
# copying from ./heroes/torbjorn\00000057.png to ./heroes\valid\torbjorn\00000057.png
# copying from ./heroes/torbjorn\00000058.jpg to ./heroes\valid\torbjorn\00000058.jpg
# copying from ./heroes/torbjorn\00000059.jpg to ./heroes\valid\torbjorn\00000059.jpg
# copying from ./heroes/torbjorn\00000060.jpg to ./heroes\valid\torbjorn\00000060.jpg
# copying from ./heroes/torbjorn\00000061.png to ./heroes\valid\torbjorn\00000061.png
# copying from ./heroes/torbjorn\00000062.jpg to ./heroes\valid\torbjorn\00000062.jpg
# copying from ./heroes/torbjorn\00000063.jpg to ./heroes\valid\torbjorn\00000063.jpg
# copying from ./heroes/torbjorn\00000064.jpg to ./heroes\valid\torbjorn\00000064.jpg
# copying from ./heroes/torbjorn\00000065.jpg to ./heroes\valid\torbjorn\00000065.jpg
# copying from ./heroes/torbjorn\00000066.jpg to ./heroes\valid\torbjorn\00000066.jpg
# copying from ./heroes/torbjorn\00000068.jpg to ./heroes\valid\torbjorn\00000068.jpg
# copying from ./heroes/torbjorn\00000069.jpg to ./heroes\valid\torbjorn\00000069.jpg
# copying from ./heroes/torbjorn\00000070.png to ./heroes\valid\torbjorn\00000070.png
# In tracer
# copying from ./heroes/tracer\00000045.png to ./heroes\valid\tracer\00000045.png
# copying from ./heroes/tracer\00000046.jpg to ./heroes\valid\tracer\00000046.jpg
# copying from ./heroes/tracer\00000047.png to ./heroes\valid\tracer\00000047.png
# copying from ./heroes/tracer\00000049.jpg to ./heroes\valid\tracer\00000049.jpg
# copying from ./heroes/tracer\00000051.jpg to ./heroes\valid\tracer\00000051.jpg
# copying from ./heroes/tracer\00000052.jpg to ./heroes\valid\tracer\00000052.jpg
# copying from ./heroes/tracer\00000053.jpg to ./heroes\valid\tracer\00000053.jpg
# copying from ./heroes/tracer\00000054.jpg to ./heroes\valid\tracer\00000054.jpg
# copying from ./heroes/tracer\00000055.jpg to ./heroes\valid\tracer\00000055.jpg
# copying from ./heroes/tracer\00000057.jpg to ./heroes\valid\tracer\00000057.jpg
# copying from ./heroes/tracer\00000058.jpg to ./heroes\valid\tracer\00000058.jpg
# copying from ./heroes/tracer\00000060.jpg to ./heroes\valid\tracer\00000060.jpg
# copying from ./heroes/tracer\00000061.jpg to ./heroes\valid\tracer\00000061.jpg
# copying from ./heroes/tracer\00000063.jpg to ./heroes\valid\tracer\00000063.jpg
# copying from ./heroes/tracer\00000064.jpg to ./heroes\valid\tracer\00000064.jpg
# copying from ./heroes/tracer\00000065.png to ./heroes\valid\tracer\00000065.png
# copying from ./heroes/tracer\00000066.jpg to ./heroes\valid\tracer\00000066.jpg
# copying from ./heroes/tracer\00000067.png to ./heroes\valid\tracer\00000067.png
# copying from ./heroes/tracer\00000068.jpg to ./heroes\valid\tracer\00000068.jpg
# copying from ./heroes/tracer\00000069.png to ./heroes\valid\tracer\00000069.png
# copying from ./heroes/tracer\00000070.jpg to ./heroes\valid\tracer\00000070.jpg
# copying from ./heroes/tracer\00000071.jpg to ./heroes\valid\tracer\00000071.jpg
# copying from ./heroes/tracer\00000072.jpg to ./heroes\valid\tracer\00000072.jpg
# copying from ./heroes/tracer\00000073.jpg to ./heroes\valid\tracer\00000073.jpg
# In widowmaker
# copying from ./heroes/widowmaker\00000044.png to ./heroes\valid\widowmaker\00000044.png
# copying from ./heroes/widowmaker\00000045.jpg to ./heroes\valid\widowmaker\00000045.jpg
# copying from ./heroes/widowmaker\00000046.jpg to ./heroes\valid\widowmaker\00000046.jpg
# copying from ./heroes/widowmaker\00000047.jpg to ./heroes\valid\widowmaker\00000047.jpg
# copying from ./heroes/widowmaker\00000048.jpg to ./heroes\valid\widowmaker\00000048.jpg
# copying from ./heroes/widowmaker\00000049.jpg to ./heroes\valid\widowmaker\00000049.jpg
# copying from ./heroes/widowmaker\00000050.jpg to ./heroes\valid\widowmaker\00000050.jpg
# copying from ./heroes/widowmaker\00000051.jpg to ./heroes\valid\widowmaker\00000051.jpg
# copying from ./heroes/widowmaker\00000052.jpg to ./heroes\valid\widowmaker\00000052.jpg
# copying from ./heroes/widowmaker\00000053.jpg to ./heroes\valid\widowmaker\00000053.jpg
# copying from ./heroes/widowmaker\00000054.jpg to ./heroes\valid\widowmaker\00000054.jpg
# copying from ./heroes/widowmaker\00000055.jpg to ./heroes\valid\widowmaker\00000055.jpg
# copying from ./heroes/widowmaker\00000056.jpg to ./heroes\valid\widowmaker\00000056.jpg
# copying from ./heroes/widowmaker\00000057.jpg to ./heroes\valid\widowmaker\00000057.jpg
# copying from ./heroes/widowmaker\00000058.jpg to ./heroes\valid\widowmaker\00000058.jpg
# copying from ./heroes/widowmaker\00000060.jpg to ./heroes\valid\widowmaker\00000060.jpg
# copying from ./heroes/widowmaker\00000061.jpg to ./heroes\valid\widowmaker\00000061.jpg
# copying from ./heroes/widowmaker\00000063.jpg to ./heroes\valid\widowmaker\00000063.jpg
# copying from ./heroes/widowmaker\00000064.jpg to ./heroes\valid\widowmaker\00000064.jpg
# copying from ./heroes/widowmaker\00000065.jpg to ./heroes\valid\widowmaker\00000065.jpg
# copying from ./heroes/widowmaker\00000066.png to ./heroes\valid\widowmaker\00000066.png
# copying from ./heroes/widowmaker\00000069.jpg to ./heroes\valid\widowmaker\00000069.jpg
# copying from ./heroes/widowmaker\00000070.jpg to ./heroes\valid\widowmaker\00000070.jpg
# copying from ./heroes/widowmaker\00000071.jpg to ./heroes\valid\widowmaker\00000071.jpg
# copying from ./heroes/widowmaker\00000072.png to ./heroes\valid\widowmaker\00000072.png
# copying from ./heroes/widowmaker\00000073.jpg to ./heroes\valid\widowmaker\00000073.jpg
# In winston
# copying from ./heroes/winston\00000043.jpg to ./heroes\valid\winston\00000043.jpg
# copying from ./heroes/winston\00000044.jpg to ./heroes\valid\winston\00000044.jpg
# copying from ./heroes/winston\00000045.JPG to ./heroes\valid\winston\00000045.JPG
# copying from ./heroes/winston\00000046.jpg to ./heroes\valid\winston\00000046.jpg
# copying from ./heroes/winston\00000047.jpg to ./heroes\valid\winston\00000047.jpg
# copying from ./heroes/winston\00000049.jpg to ./heroes\valid\winston\00000049.jpg
# copying from ./heroes/winston\00000050.jpg to ./heroes\valid\winston\00000050.jpg
# copying from ./heroes/winston\00000051.png to ./heroes\valid\winston\00000051.png
# copying from ./heroes/winston\00000052.jpg to ./heroes\valid\winston\00000052.jpg
# copying from ./heroes/winston\00000054.png to ./heroes\valid\winston\00000054.png
# copying from ./heroes/winston\00000055.jpg to ./heroes\valid\winston\00000055.jpg
# copying from ./heroes/winston\00000056.jpg to ./heroes\valid\winston\00000056.jpg
# copying from ./heroes/winston\00000057.jpg to ./heroes\valid\winston\00000057.jpg
# copying from ./heroes/winston\00000058.jpg to ./heroes\valid\winston\00000058.jpg
# copying from ./heroes/winston\00000059.jpg to ./heroes\valid\winston\00000059.jpg
# copying from ./heroes/winston\00000060.jpg to ./heroes\valid\winston\00000060.jpg
# copying from ./heroes/winston\00000061.png to ./heroes\valid\winston\00000061.png
# copying from ./heroes/winston\00000062.jpg to ./heroes\valid\winston\00000062.jpg
# copying from ./heroes/winston\00000063.jpg to ./heroes\valid\winston\00000063.jpg
# copying from ./heroes/winston\00000065.jpg to ./heroes\valid\winston\00000065.jpg
# copying from ./heroes/winston\00000067.jpg to ./heroes\valid\winston\00000067.jpg
# copying from ./heroes/winston\00000068.jpg to ./heroes\valid\winston\00000068.jpg
# copying from ./heroes/winston\00000069.jpg to ./heroes\valid\winston\00000069.jpg
# In zarya
# copying from ./heroes/zarya\00000047.png to ./heroes\valid\zarya\00000047.png
# copying from ./heroes/zarya\00000048.jpg to ./heroes\valid\zarya\00000048.jpg
# copying from ./heroes/zarya\00000049.jpg to ./heroes\valid\zarya\00000049.jpg
# copying from ./heroes/zarya\00000050.jpg to ./heroes\valid\zarya\00000050.jpg
# copying from ./heroes/zarya\00000051.jpg to ./heroes\valid\zarya\00000051.jpg
# copying from ./heroes/zarya\00000052.jpg to ./heroes\valid\zarya\00000052.jpg
# copying from ./heroes/zarya\00000053.jpg to ./heroes\valid\zarya\00000053.jpg
# copying from ./heroes/zarya\00000054.jpg to ./heroes\valid\zarya\00000054.jpg
# copying from ./heroes/zarya\00000055.jpg to ./heroes\valid\zarya\00000055.jpg
# copying from ./heroes/zarya\00000056.jpg to ./heroes\valid\zarya\00000056.jpg
# copying from ./heroes/zarya\00000057.jpg to ./heroes\valid\zarya\00000057.jpg
# copying from ./heroes/zarya\00000058.png to ./heroes\valid\zarya\00000058.png
# copying from ./heroes/zarya\00000060.jpg to ./heroes\valid\zarya\00000060.jpg
# copying from ./heroes/zarya\00000061.png to ./heroes\valid\zarya\00000061.png
# copying from ./heroes/zarya\00000062.jpg to ./heroes\valid\zarya\00000062.jpg
# copying from ./heroes/zarya\00000065.jpg to ./heroes\valid\zarya\00000065.jpg
# copying from ./heroes/zarya\00000067.jpg to ./heroes\valid\zarya\00000067.jpg
# copying from ./heroes/zarya\00000069.jpg to ./heroes\valid\zarya\00000069.jpg
# copying from ./heroes/zarya\00000070.jpg to ./heroes\valid\zarya\00000070.jpg
# copying from ./heroes/zarya\00000071.jpg to ./heroes\valid\zarya\00000071.jpg
# copying from ./heroes/zarya\00000074.jpg to ./heroes\valid\zarya\00000074.jpg
# copying from ./heroes/zarya\00000075.png to ./heroes\valid\zarya\00000075.png
# In zenyatta
# copying from ./heroes/zenyatta\00000046.jpg to ./heroes\valid\zenyatta\00000046.jpg
# copying from ./heroes/zenyatta\00000047.jpg to ./heroes\valid\zenyatta\00000047.jpg
# copying from ./heroes/zenyatta\00000048.jpg to ./heroes\valid\zenyatta\00000048.jpg
# copying from ./heroes/zenyatta\00000049.png to ./heroes\valid\zenyatta\00000049.png
# copying from ./heroes/zenyatta\00000050.jpg to ./heroes\valid\zenyatta\00000050.jpg
# copying from ./heroes/zenyatta\00000051.png to ./heroes\valid\zenyatta\00000051.png
# copying from ./heroes/zenyatta\00000052.jpg to ./heroes\valid\zenyatta\00000052.jpg
# copying from ./heroes/zenyatta\00000053.jpg to ./heroes\valid\zenyatta\00000053.jpg
# copying from ./heroes/zenyatta\00000054.jpg to ./heroes\valid\zenyatta\00000054.jpg
# copying from ./heroes/zenyatta\00000055.jpg to ./heroes\valid\zenyatta\00000055.jpg
# copying from ./heroes/zenyatta\00000056.png to ./heroes\valid\zenyatta\00000056.png
# copying from ./heroes/zenyatta\00000058.png to ./heroes\valid\zenyatta\00000058.png
# copying from ./heroes/zenyatta\00000059.jpg to ./heroes\valid\zenyatta\00000059.jpg
# copying from ./heroes/zenyatta\00000060.jpg to ./heroes\valid\zenyatta\00000060.jpg
# copying from ./heroes/zenyatta\00000061.jpg to ./heroes\valid\zenyatta\00000061.jpg
# copying from ./heroes/zenyatta\00000062.jpg to ./heroes\valid\zenyatta\00000062.jpg
# copying from ./heroes/zenyatta\00000063.jpg to ./heroes\valid\zenyatta\00000063.jpg
# copying from ./heroes/zenyatta\00000064.jpg to ./heroes\valid\zenyatta\00000064.jpg
# copying from ./heroes/zenyatta\00000065.png to ./heroes\valid\zenyatta\00000065.png
# copying from ./heroes/zenyatta\00000066.jpg to ./heroes\valid\zenyatta\00000066.jpg
# copying from ./heroes/zenyatta\00000067.jpg to ./heroes\valid\zenyatta\00000067.jpg
# copying from ./heroes/zenyatta\00000068.jpg to ./heroes\valid\zenyatta\00000068.jpg
# copying from ./heroes/zenyatta\00000069.jpg to ./heroes\valid\zenyatta\00000069.jpg
# copying from ./heroes/zenyatta\00000070.jpg to ./heroes\valid\zenyatta\00000070.jpg

# %%
#copia os dados para pasta de testes
for tag in tags:
    if tag != ".ipynb_checkpoints":
        print(f"In {tag}")     
        match = [f for f in os.listdir(pathname+f"{tag}") if f[0].isdigit()] 
        train_fac = 0.5 
        valid_fac = 0.3
        test_fac  = 0.2        
        train_length = int(len(match)*train_fac)
        valid_length = train_length + int(len(match)*valid_fac)
        test_length =  train_length + valid_length + int(len(match)*test_fac)        
        for i in range(valid_length, len(match)):             
            src = os.path.join(pathname+f"{tag}", match[i])
            dst = os.path.join(named_test_dirs[tag], match[i])
            print(f"copying from {src} to {dst}")
            shutil.copyfile(src, dst)
# Out:
#  ./heroes\test\mercy\00000088.jpg
# copying from ./heroes/mercy\00000089.jpg to ./heroes\test\mercy\00000089.jpg
# copying from ./heroes/mercy\00000091.jpg to ./heroes\test\mercy\00000091.jpg
# copying from ./heroes/mercy\00000092.png to ./heroes\test\mercy\00000092.png
# copying from ./heroes/mercy\00000093.jpg to ./heroes\test\mercy\00000093.jpg
# copying from ./heroes/mercy\00000094.jpg to ./heroes\test\mercy\00000094.jpg
# copying from ./heroes/mercy\00000095.jpg to ./heroes\test\mercy\00000095.jpg
# copying from ./heroes/mercy\00000096.jpg to ./heroes\test\mercy\00000096.jpg
# In moira
# copying from ./heroes/moira\00000076.jpg to ./heroes\test\moira\00000076.jpg
# copying from ./heroes/moira\00000078.jpg to ./heroes\test\moira\00000078.jpg
# copying from ./heroes/moira\00000079.jpg to ./heroes\test\moira\00000079.jpg
# copying from ./heroes/moira\00000080.png to ./heroes\test\moira\00000080.png
# copying from ./heroes/moira\00000081.png to ./heroes\test\moira\00000081.png
# copying from ./heroes/moira\00000082.png to ./heroes\test\moira\00000082.png
# copying from ./heroes/moira\00000083.jpg to ./heroes\test\moira\00000083.jpg
# copying from ./heroes/moira\00000084.jpg to ./heroes\test\moira\00000084.jpg
# copying from ./heroes/moira\00000086.jpg to ./heroes\test\moira\00000086.jpg
# copying from ./heroes/moira\00000088.jpg to ./heroes\test\moira\00000088.jpg
# copying from ./heroes/moira\00000089.jpg to ./heroes\test\moira\00000089.jpg
# copying from ./heroes/moira\00000090.jpg to ./heroes\test\moira\00000090.jpg
# copying from ./heroes/moira\00000091.jpg to ./heroes\test\moira\00000091.jpg
# copying from ./heroes/moira\00000092.png to ./heroes\test\moira\00000092.png
# copying from ./heroes/moira\00000093.jpg to ./heroes\test\moira\00000093.jpg
# copying from ./heroes/moira\00000095.png to ./heroes\test\moira\00000095.png
# copying from ./heroes/soldier76\00000079.jpg to ./heroes\test\soldier76\00000079.jpg
# copying from ./heroes/soldier76\00000080.jpg to ./heroes\test\soldier76\00000080.jpg
# copying from ./heroes/soldier76\00000081.jpg to ./heroes\test\soldier76\00000081.jpg
# copying from ./heroes/soldier76\00000082.jpg to ./heroes\test\soldier76\00000082.jpg
# copying from ./heroes/soldier76\00000083.png to ./heroes\test\soldier76\00000083.png
# copying from ./heroes/soldier76\00000084.png to ./heroes\test\soldier76\00000084.png
# copying from ./heroes/soldier76\00000086.jpg to ./heroes\test\soldier76\00000086.jpg
# copying from ./heroes/soldier76\00000087.jpg to ./heroes\test\soldier76\00000087.jpg
# copying from ./heroes/soldier76\00000088.jpg to ./heroes\test\soldier76\00000088.jpg
# copying from ./heroes/soldier76\00000090.jpg to ./heroes\test\soldier76\00000090.jpg
# copying from ./heroes/soldier76\00000091.jpg to ./heroes\test\soldier76\00000091.jpg
# copying from ./heroes/soldier76\00000092.jpg to ./heroes\test\soldier76\00000092.jpg
# In sombra
# copying from ./heroes/sombra\00000070.png to ./heroes\test\sombra\00000070.png
# copying from ./heroes/sombra\00000071.jpg to ./heroes\test\sombra\00000071.jpg
# copying from ./heroes/sombra\00000072.jpg to ./heroes\test\sombra\00000072.jpg
# copying from ./heroes/sombra\00000073.jpg to ./heroes\test\sombra\00000073.jpg
# copying from ./heroes/sombra\00000074.jpg to ./heroes\test\sombra\00000074.jpg
# copying from ./heroes/sombra\00000075.jpg to ./heroes\test\sombra\00000075.jpg
# copying from ./heroes/sombra\00000076.jpg to ./heroes\test\sombra\00000076.jpg
# copying from ./heroes/sombra\00000077.png to ./heroes\test\sombra\00000077.png
# copying from ./heroes/sombra\00000079.jpg to ./heroes\test\sombra\00000079.jpg
# copying from ./heroes/sombra\00000080.jpg to ./heroes\test\sombra\00000080.jpg
# copying from ./heroes/sombra\00000081.jpg to ./heroes\test\sombra\00000081.jpg
# copying from ./heroes/sombra\00000082.png to ./heroes\test\sombra\00000082.png
# copying from ./heroes/sombra\00000084.jpg to ./heroes\test\sombra\00000084.jpg
# copying from ./heroes/sombra\00000085.jpg to ./heroes\test\sombra\00000085.jpg
# copying from ./heroes/sombra\00000086.jpg to ./heroes\test\sombra\00000086.jpg
# copying from ./heroes/sombra\00000087.jpg to ./heroes\test\sombra\00000087.jpg
# copying from ./heroes/sombra\00000089.jpg to ./heroes\test\sombra\00000089.jpg
# In symmetra
# copying from ./heroes/symmetra\00000076.jpg to ./heroes\test\symmetra\00000076.jpg
# copying from ./heroes/symmetra\00000077.jpg to ./heroes\test\symmetra\00000077.jpg
# copying from ./heroes/symmetra\00000079.png to ./heroes\test\symmetra\00000079.png
# copying from ./heroes/symmetra\00000080.jpg to ./heroes\test\symmetra\00000080.jpg
# copying from ./heroes/symmetra\00000082.jpg to ./heroes\test\symmetra\00000082.jpg
# copying from ./heroes/symmetra\00000083.JPG to ./heroes\test\symmetra\00000083.JPG
# copying from ./heroes/symmetra\00000084.png to ./heroes\test\symmetra\00000084.png
# copying from ./heroes/symmetra\00000086.jpg to ./heroes\test\symmetra\00000086.jpg
# copying from ./heroes/symmetra\00000087.jpg to ./heroes\test\symmetra\00000087.jpg
# copying from ./heroes/symmetra\00000088.jpg to ./heroes\test\symmetra\00000088.jpg
# copying from ./heroes/symmetra\00000089.jpg to ./heroes\test\symmetra\00000089.jpg
# copying from ./heroes/symmetra\00000090.jpg to ./heroes\test\symmetra\00000090.jpg
# copying from ./heroes/symmetra\00000091.jpg to ./heroes\test\symmetra\00000091.jpg
# copying from ./heroes/symmetra\00000093.jpg to ./heroes\test\symmetra\00000093.jpg
# copying from ./heroes/symmetra\00000094.jpg to ./heroes\test\symmetra\00000094.jpg
# copying from ./heroes/symmetra\00000095.jpg to ./heroes\test\symmetra\00000095.jpg
# In torbjorn
# copying from ./heroes/torbjorn\00000071.jpg to ./heroes\test\torbjorn\00000071.jpg
# copying from ./heroes/torbjorn\00000072.jpg to ./heroes\test\torbjorn\00000072.jpg
# copying from ./heroes/torbjorn\00000074.png to ./heroes\test\torbjorn\00000074.png
# copying from ./heroes/torbjorn\00000075.jpg to ./heroes\test\torbjorn\00000075.jpg
# copying from ./heroes/torbjorn\00000076.jpg to ./heroes\test\torbjorn\00000076.jpg
# copying from ./heroes/torbjorn\00000077.png to ./heroes\test\torbjorn\00000077.png
# copying from ./heroes/torbjorn\00000078.jpg to ./heroes\test\torbjorn\00000078.jpg
# copying from ./heroes/torbjorn\00000079.jpg to ./heroes\test\torbjorn\00000079.jpg
# copying from ./heroes/torbjorn\00000080.jpg to ./heroes\test\torbjorn\00000080.jpg
# copying from ./heroes/torbjorn\00000082.jpg to ./heroes\test\torbjorn\00000082.jpg
# copying from ./heroes/torbjorn\00000084.jpg to ./heroes\test\torbjorn\00000084.jpg
# copying from ./heroes/torbjorn\00000085.jpg to ./heroes\test\torbjorn\00000085.jpg
# copying from ./heroes/torbjorn\00000086.png to ./heroes\test\torbjorn\00000086.png
# copying from ./heroes/torbjorn\00000087.jpg to ./heroes\test\torbjorn\00000087.jpg
# copying from ./heroes/torbjorn\00000088.jpg to ./heroes\test\torbjorn\00000088.jpg
# copying from ./heroes/torbjorn\00000089.jpg to ./heroes\test\torbjorn\00000089.jpg
# In tracer
# copying from ./heroes/tracer\00000076.jpg to ./heroes\test\tracer\00000076.jpg
# copying from ./heroes/tracer\00000077.jpg to ./heroes\test\tracer\00000077.jpg
# copying from ./heroes/tracer\00000078.jpg to ./heroes\test\tracer\00000078.jpg
# copying from ./heroes/tracer\00000079.jpg to ./heroes\test\tracer\00000079.jpg
# copying from ./heroes/tracer\00000080.jpg to ./heroes\test\tracer\00000080.jpg
# copying from ./heroes/tracer\00000081.jpg to ./heroes\test\tracer\00000081.jpg
# copying from ./heroes/tracer\00000082.png to ./heroes\test\tracer\00000082.png
# copying from ./heroes/tracer\00000084.jpg to ./heroes\test\tracer\00000084.jpg
# copying from ./heroes/tracer\00000086.jpg to ./heroes\test\tracer\00000086.jpg
# copying from ./heroes/tracer\00000087.jpg to ./heroes\test\tracer\00000087.jpg
# copying from ./heroes/tracer\00000088.jpg to ./heroes\test\tracer\00000088.jpg
# copying from ./heroes/tracer\00000089.png to ./heroes\test\tracer\00000089.png
# copying from ./heroes/tracer\00000091.jpg to ./heroes\test\tracer\00000091.jpg
# copying from ./heroes/tracer\00000094.jpg to ./heroes\test\tracer\00000094.jpg
# copying from ./heroes/tracer\00000095.jpg to ./heroes\test\tracer\00000095.jpg
# copying from ./heroes/tracer\00000097.jpg to ./heroes\test\tracer\00000097.jpg
# copying from ./heroes/tracer\1c26ca90328416ef19c1438fa529a42c.tracer-ptr-buff-overwatch.jpg to ./heroes\test\tracer\1c26ca90328416ef19c1438fa529a42c.tracer-ptr-buff-overwatch.jpg
# copying from ./heroes/tracer\28c22a1f-df59-4cf2-8daa-56d9c5ada9a0.jfif to ./heroes\test\tracer\28c22a1f-df59-4cf2-8daa-56d9c5ada9a0.jfif
# In widowmaker
# copying from ./heroes/widowmaker\00000074.jpg to ./heroes\test\widowmaker\00000074.jpg
# copying from ./heroes/widowmaker\00000075.png to ./heroes\test\widowmaker\00000075.png
# copying from ./heroes/widowmaker\00000076.jpg to ./heroes\test\widowmaker\00000076.jpg
# copying from ./heroes/widowmaker\00000077.jpg to ./heroes\test\widowmaker\00000077.jpg
# copying from ./heroes/widowmaker\00000078.jpg to ./heroes\test\widowmaker\00000078.jpg
# copying from ./heroes/widowmaker\00000080.jpg to ./heroes\test\widowmaker\00000080.jpg
# copying from ./heroes/widowmaker\00000082.jpg to ./heroes\test\widowmaker\00000082.jpg
# copying from ./heroes/widowmaker\00000083.jpg to ./heroes\test\widowmaker\00000083.jpg
# copying from ./heroes/widowmaker\00000084.jpg to ./heroes\test\widowmaker\00000084.jpg
# copying from ./heroes/widowmaker\00000085.jpg to ./heroes\test\widowmaker\00000085.jpg
# copying from ./heroes/widowmaker\00000086.png to ./heroes\test\widowmaker\00000086.png
# copying from ./heroes/widowmaker\00000087.jpg to ./heroes\test\widowmaker\00000087.jpg
# copying from ./heroes/widowmaker\00000088.jpg to ./heroes\test\widowmaker\00000088.jpg
# copying from ./heroes/widowmaker\00000089.jpg to ./heroes\test\widowmaker\00000089.jpg
# copying from ./heroes/widowmaker\00000090.jpg to ./heroes\test\widowmaker\00000090.jpg
# copying from ./heroes/widowmaker\00000091.jpg to ./heroes\test\widowmaker\00000091.jpg
# copying from ./heroes/widowmaker\00000092.jpg to ./heroes\test\widowmaker\00000092.jpg
# copying from ./heroes/widowmaker\00000093.jpg to ./heroes\test\widowmaker\00000093.jpg
# In winston
# copying from ./heroes/winston\00000070.jpg to ./heroes\test\winston\00000070.jpg
# copying from ./heroes/winston\00000071.jpg to ./heroes\test\winston\00000071.jpg
# copying from ./heroes/winston\00000072.jpg to ./heroes\test\winston\00000072.jpg
# copying from ./heroes/winston\00000073.jpg to ./heroes\test\winston\00000073.jpg
# copying from ./heroes/winston\00000076.png to ./heroes\test\winston\00000076.png
# copying from ./heroes/winston\00000077.jpg to ./heroes\test\winston\00000077.jpg
# copying from ./heroes/winston\00000078.jpg to ./heroes\test\winston\00000078.jpg
# copying from ./heroes/winston\00000079.png to ./heroes\test\winston\00000079.png
# copying from ./heroes/winston\00000080.png to ./heroes\test\winston\00000080.png
# copying from ./heroes/winston\00000081.jpg to ./heroes\test\winston\00000081.jpg
# copying from ./heroes/winston\00000082.jpg to ./heroes\test\winston\00000082.jpg
# copying from ./heroes/winston\00000083.JPG to ./heroes\test\winston\00000083.JPG
# copying from ./heroes/winston\00000085.png to ./heroes\test\winston\00000085.png
# copying from ./heroes/winston\00000086.jpg to ./heroes\test\winston\00000086.jpg
# copying from ./heroes/winston\00000087.jpg to ./heroes\test\winston\00000087.jpg
# copying from ./heroes/winston\00000088.jpg to ./heroes\test\winston\00000088.jpg
# In zarya
# copying from ./heroes/zarya\00000076.jpg to ./heroes\test\zarya\00000076.jpg
# copying from ./heroes/zarya\00000077.jpg to ./heroes\test\zarya\00000077.jpg
# copying from ./heroes/zarya\00000078.jpg to ./heroes\test\zarya\00000078.jpg
# copying from ./heroes/zarya\00000079.jpg to ./heroes\test\zarya\00000079.jpg
# copying from ./heroes/zarya\00000080.png to ./heroes\test\zarya\00000080.png
# copying from ./heroes/zarya\00000082.jpg to ./heroes\test\zarya\00000082.jpg
# copying from ./heroes/zarya\00000083.jpg to ./heroes\test\zarya\00000083.jpg
# copying from ./heroes/zarya\00000084.png to ./heroes\test\zarya\00000084.png
# copying from ./heroes/zarya\00000085.jpg to ./heroes\test\zarya\00000085.jpg
# copying from ./heroes/zarya\00000087.jpg to ./heroes\test\zarya\00000087.jpg
# copying from ./heroes/zarya\00000088.jpg to ./heroes\test\zarya\00000088.jpg
# copying from ./heroes/zarya\00000089.png to ./heroes\test\zarya\00000089.png
# copying from ./heroes/zarya\00000090.jpg to ./heroes\test\zarya\00000090.jpg
# copying from ./heroes/zarya\00000091.jpg to ./heroes\test\zarya\00000091.jpg
# copying from ./heroes/zarya\00000092.png to ./heroes\test\zarya\00000092.png
# copying from ./heroes/zarya\00000093.jpg to ./heroes\test\zarya\00000093.jpg
# In zenyatta
# copying from ./heroes/zenyatta\00000071.jpg to ./heroes\test\zenyatta\00000071.jpg
# copying from ./heroes/zenyatta\00000072.jpg to ./heroes\test\zenyatta\00000072.jpg
# copying from ./heroes/zenyatta\00000073.jpg to ./heroes\test\zenyatta\00000073.jpg
# copying from ./heroes/zenyatta\00000074.jpg to ./heroes\test\zenyatta\00000074.jpg
# copying from ./heroes/zenyatta\00000075.jpg to ./heroes\test\zenyatta\00000075.jpg
# copying from ./heroes/zenyatta\00000076.jpg to ./heroes\test\zenyatta\00000076.jpg
# copying from ./heroes/zenyatta\00000078.jpg to ./heroes\test\zenyatta\00000078.jpg
# copying from ./heroes/zenyatta\00000079.jpg to ./heroes\test\zenyatta\00000079.jpg
# copying from ./heroes/zenyatta\00000080.jpg to ./heroes\test\zenyatta\00000080.jpg
# copying from ./heroes/zenyatta\00000082.png to ./heroes\test\zenyatta\00000082.png
# copying from ./heroes/zenyatta\00000083.png to ./heroes\test\zenyatta\00000083.png
# copying from ./heroes/zenyatta\00000085.jpg to ./heroes\test\zenyatta\00000085.jpg
# copying from ./heroes/zenyatta\00000087.jpg to ./heroes\test\zenyatta\00000087.jpg
# copying from ./heroes/zenyatta\00000088.jpg to ./heroes\test\zenyatta\00000088.jpg
# copying from ./heroes/zenyatta\00000089.png to ./heroes\test\zenyatta\00000089.png
# copying from ./heroes/zenyatta\00000090.jpg to ./heroes\test\zenyatta\00000090.jpg
# copying from ./heroes/zenyatta\00000091.jpg to ./heroes\test\zenyatta\00000091.jpg
# copying from ./heroes/zenyatta\00000092.jpg to ./heroes\test\zenyatta\00000092.jpg

# %%
#Configuracoes para KerasImageDataGenerator
DataGeneratorParams = {}
DataGeneratorParams["rescale"] = 1./255
DataGeneratorParams["rotation_range"] = 90
DataGeneratorParams["width_shift_range"] = 0.3
DataGeneratorParams["height_shift_range"] = 0.3
DataGeneratorParams["shear_range"] = 0.3
DataGeneratorParams["zoom_range"] = 0.3
DataGeneratorParams["horizontal_flip"] = True

# %%
#training
train_datagen = ImageDataGenerator(**DataGeneratorParams)
#validation
valid_datagen = ImageDataGenerator(**DataGeneratorParams)
#test
test_datagen = ImageDataGenerator(**DataGeneratorParams)

# %%
#Configuracoes para datagen
datagen = {}
datagen["target_size"] = (512,512)
datagen["batch_size"] = 10
datagen["classes"] = tags

# %%
train_generator = train_datagen.flow_from_directory(train_dir,  **datagen)
valid_generator = valid_datagen.flow_from_directory(valid_dir,**datagen)
test_generator  = test_datagen.flow_from_directory(test_dir, **datagen)
# Out:
# Found 1074 images belonging to 30 classes.
# Found 637 images belonging to 30 classes.
# Found 450 images belonging to 30 classes.

# %%
from tensorflow.keras import models
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

# %%
def build_network(input_shape, num_classes):
    model = models.Sequential()
    model.add(Conv2D(filters=64, \
                     kernel_size=(7,7), \
                     padding="same", activation="relu", input_shape=input_shape)) 
    model.add(Conv2D(filters=32, \
                     kernel_size=(5,5), \
                     padding="same", activation="relu")) 
    model.add(Conv2D(filters=16, \
                     kernel_size=(5,5), \
                     padding="same", activation="relu"))        
    model.add(Flatten())
    model.add(Dense(num_classes, activation="softmax"))
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
import tensorflow

physical_devices = tensorflow.config.experimental.list_physical_devices('GPU')

if physical_devices:
    for dev in physical_devices:
        tf.config.experimental.set_memory_growth(dev, True)  
        
dt = len(tensorflow.config.experimental.list_physical_devices('GPU'))
print("Num GPUs Available: ",dt )
print("tf version: ",tensorflow.__version__)
device = ""
if dt < 1:
    print("No GPU Available, reverting to cpu")
    device = "cpu"
else:
    device = "gpu"
    
print(f"device: {device}, enabled")
# Out:
# Num GPUs Available:  0
# tf version:  2.4.1
# No GPU Available, reverting to cpu
# device: cpu, enabled

# %%
INPUT_SHAPE = (512,512,3)
NUM_CLASSES = 30
model = build_network(INPUT_SHAPE, NUM_CLASSES)

# %%
history = model.fit(train_generator, steps_per_epoch=10, epochs=30, validation_data=valid_generator, validation_steps=10)

# %%
import matplotlib.pyplot as plt

acc     = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss    = history.history["loss"]
val_loss    = history.history["val_loss"]

epochs = range(1, len(acc) + 1)

# %%
plt.plot(epochs, acc, label="training accuracy")
plt.plot(epochs, val_acc, label="validation accuracy" )
plt.title("Training and validation accuracy")
plt.legend()

# %%
plt.plot(epochs, loss, label="training loss")
plt.plot(epochs, val_loss, label="validation loss" )
plt.title("Training and validation loss")
plt.legend()
